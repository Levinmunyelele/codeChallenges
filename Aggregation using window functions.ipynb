# %% [markdown]
# # Aggregation using window functions
# © ExploreAI Academy

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# - Understand the concept of window functions in SQL.
# - Learn how to use window functions for data aggregation.
# - Understand how to use window functions to partition data.
# - Practise using window functions to solve complex problems.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore how to use window functions in SQL to solve complex problems. Window functions are a type of function in SQL that performs a calculation across a set of table rows that are related to the current row.
#
# We will use the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their GDP, and access to basic services.
#
# Let's begin by calculating each country's land cover as a percentage per subregion for the year 2020.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook.

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name.

# %sql mysql+pymysql://root:Mysql5918.2018@localhost:3306/united_nations
# Out:
# 'Connected: root@united_nations'

# %% [markdown]
# ## Exercise
#
# ### Task 1: Select the data required for the analysis
#
# The columns you select should include:
# - `Sub_region`
# - `Country_name`
# - `Land_area`
#
# Filter out the results using the following criteria:
# - For the `Time_period` of `2020`.
# - For `Land_area` values that are not missing.

# %%
# %%sql
# SELECT
# 	Sub_region,
#     Country_name,
#     Land_area
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020
# AND Land_area IS NOT NULL;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 130 rows affected.
# [('Central Asia', 'Kazakhstan', Decimal('2699700.00')),
#  ('Central Asia', 'Tajikistan', Decimal('138790.00')),
#  ('Central Asia', 'Turkmenistan', Decimal('469930.00')),
#  ('Central Asia', 'Uzbekistan', Decimal('440650.00')),
#  ('Southern Asia', 'Afghanistan', Decimal('652230.00')),
#  ('Southern Asia', 'Bangladesh', Decimal('130170.00')),
#  ('Southern Asia', 'Bhutan', Decimal('38140.00')),
#  ('Southern Asia', 'India', Decimal('2973190.00')),
#  ('Southern Asia', 'Maldives', Decimal('300.00')),
#  ('Southern Asia', 'Nepal', Decimal('143350.00')),
#  ('Southern Asia', 'Pakistan', Decimal('770880.00')),
#  ('Southern Asia', 'Sri Lanka', Decimal('61860.00')),
#  ('Eastern Asia', 'China', Decimal('9424702.90')),
#  ('Eastern Asia', 'Japan', Decimal('364500.00')),
#  ('Eastern Asia', 'Mongolia', Decimal('1557506.80')),
#  ('South-Eastern Asia', 'Brunei Darussalam', Decimal('5270.00')),
#  ('South-Eastern Asia', 'Cambodia', Decimal('176520.00')),
#  ('South-Eastern Asia', 'Indonesia', Decimal('1877519.00')),
#  ('South-Eastern Asia', 'Malaysia', Decimal('328550.00')),
#  ('South-Eastern Asia', 'Myanmar', Decimal('652670.00')),
#  ('South-Eastern Asia', 'Philippines', Decimal('298170.00')),
#  ('South-Eastern Asia', 'Singapore', Decimal('718.00')),
#  ('South-Eastern Asia', 'Thailand', Decimal('510890.00')),
#  ('South-Eastern Asia', 'Timor-Leste', Decimal('14870.00')),
#  ('Northern America', 'Bermuda', Decimal('54.00')),
#  ('Northern America', 'Canada', Decimal('8965590.00')),
#  ('Northern America', 'Greenland', Decimal('410450.00')),
#  ('Caribbean', 'Barbados', Decimal('430.00')),
#  ('Caribbean', 'British Virgin Islands', Decimal('150.00')),
#  ('Caribbean', 'Cuba', Decimal('103800.00')),
#  ('Caribbean', 'Dominican Republic', Decimal('48310.00')),
#  ('Caribbean', 'Haiti', Decimal('27560.00')),
#  ('Caribbean', 'Jamaica', Decimal('10830.00')),
#  ('Caribbean', 'Puerto Rico', Decimal('8870.00')),
#  ('Caribbean', 'Trinidad and Tobago', Decimal('5130.00')),
#  ('Central America', 'Belize', Decimal('22810.00')),
#  ('Central America', 'Costa Rica', Decimal('51060.00')),
#  ('Central America', 'El Salvador', Decimal('20720.00')),
#  ('Central America', 'Guatemala', Decimal('107160.00')),
#  ('Central America', 'Honduras', Decimal('111890.00')),
#  ('Central America', 'Mexico', Decimal('1943950.00')),
#  ('Central America', 'Nicaragua', Decimal('120340.00')),
#  ('Central America', 'Panama', Decimal('74180.00')),
#  ('South America', 'Argentina', Decimal('2736690.00')),
#  ('South America', 'Brazil', Decimal('8358140.00')),
#  ('South America', 'Chile', Decimal('743532.00')),
#  ('South America', 'Colombia', Decimal('1109500.00')),
#  ('South America', 'Ecuador', Decimal('248360.00')),
#  ('South America', 'Guyana', Decimal('196850.00')),
#  ('South America', 'Paraguay', Decimal('397300.00')),
#  ('South America', 'Peru', Decimal('1280000.00')),
#  ('South America', 'Suriname', Decimal('156000.00')),
#  ('South America', 'Uruguay', Decimal('175020.00')),
#  ('Northern Africa', 'Algeria', Decimal('2381741.00')),
#  ('Northern Africa', 'Libya', Decimal('1759540.00')),
#  ('Northern Africa', 'Morocco', Decimal('446300.00')),
#  ('Northern Africa', 'Sudan', Decimal('1868000.00')),
#  ('Northern Africa', 'Tunisia', Decimal('155360.00')),
#  ('Western Asia', 'Armenia', Decimal('28470.00')),
#  ('Western Asia', 'Azerbaijan', Decimal('82646.00')),
#  ('Western Asia', 'Bahrain', Decimal('785.00')),
#  ('Western Asia', 'Cyprus', Decimal('9240.00')),
#  ('Western Asia', 'Georgia', Decimal('69490.00')),
#  ('Western Asia', 'Iraq', Decimal('434128.00')),
#  ('Western Asia', 'Israel', Decimal('21640.00')),
#  ('Western Asia', 'Jordan', Decimal('88794.00')),
#  ('Western Asia', 'Kuwait', Decimal('17820.00')),
#  ('Western Asia', 'Lebanon', Decimal('10230.00')),
#  ('Western Asia', 'Oman', Decimal('309500.00')),
#  ('Western Asia', 'Qatar', Decimal('11490.00')),
#  ('Western Asia', 'Saudi Arabia', Decimal('2149690.00')),
#  ('Western Asia', 'Syrian Arab Republic', Decimal('183630.00')),
#  ('Western Asia', 'United Arab Emirates', Decimal('71020.00')),
#  ('Australia and New Zealand', 'Australia', Decimal('7692020.00')),
#  ('Australia and New Zealand', 'New Zealand', Decimal('263310.00')),
#  ('Melanesia', 'Fiji', Decimal('18270.00')),
#  ('Melanesia', 'New Caledonia', Decimal('18280.00')),
#  ('Melanesia', 'Papua New Guinea', Decimal('452860.00')),
#  ('Melanesia', 'Solomon Islands', Decimal('27990.00')),
#  ('Melanesia', 'Vanuatu', Decimal('12190.00')),
#  ('Micronesia', 'Guam', Decimal('540.00')),
#  ('Micronesia', 'Kiribati', Decimal('810.00')),
#  ('Micronesia', 'Marshall Islands', Decimal('180.00')),
#  ('Micronesia', 'Nauru', Decimal('20.00')),
#  ('Micronesia', 'Northern Mariana Islands', Decimal('460.00')),
#  ('Micronesia', 'Palau', Decimal('460.00')),
#  ('Polynesia', 'American Samoa', Decimal('200.00')),
#  ('Polynesia', 'French Polynesia', Decimal('3471.00')),
#  ('Polynesia', 'Samoa', Decimal('2780.00')),
#  ('Polynesia', 'Tonga', Decimal('720.00')),
#  ('Polynesia', 'Tuvalu', Decimal('30.00')),
#  ('Eastern Africa', 'Burundi', Decimal('25680.00')),
#  ('Eastern Africa', 'Djibouti', Decimal('23180.00')),
#  ('Eastern Africa', 'Ethiopia', Decimal('1128571.26')),
#  ('Eastern Africa', 'Kenya', Decimal('569140.00')),
#  ('Eastern Africa', 'Madagascar', Decimal('581800.00')),
#  ('Eastern Africa', 'Malawi', Decimal('94280.00')),
#  ('Eastern Africa', 'Mauritius', Decimal('2030.00')),
#  ('Eastern Africa', 'Mozambique', Decimal('786380.00')),
#  ('Eastern Africa', 'Rwanda', Decimal('24670.00')),
#  ('Eastern Africa', 'Somalia', Decimal('627340.00')),
#  ('Eastern Africa', 'South Sudan', Decimal('631930.00')),
#  ('Eastern Africa', 'Uganda', Decimal('200520.00')),
#  ('Eastern Africa', 'Zambia', Decimal('743390.00')),
#  ('Eastern Africa', 'Zimbabwe', Decimal('386850.00')),
#  ('Middle Africa', 'Angola', Decimal('1246700.00')),
#  ('Middle Africa', 'Cameroon', Decimal('472710.00')),
#  ('Middle Africa', 'Central African Republic', Decimal('622980.00')),
#  ('Middle Africa', 'Chad', Decimal('1259200.00')),
#  ('Middle Africa', 'Gabon', Decimal('257670.00')),
#  ('Middle Africa', 'Sao Tome and Principe', Decimal('960.00')),
#  ('Southern Africa', 'Botswana', Decimal('566730.00')),
#  ('Southern Africa', 'Eswatini', Decimal('17200.00')),
#  ('Southern Africa', 'Lesotho', Decimal('30360.00')),
#  ('Southern Africa', 'Namibia', Decimal('823290.00')),
#  ('Southern Africa', 'South Africa', Decimal('1213090.00')),
#  ('Western Africa', 'Benin', Decimal('112760.00')),
#  ('Western Africa', 'Burkina Faso', Decimal('273600.00')),
#  ('Western Africa', 'Cabo Verde', Decimal('4030.00')),
#  ('Western Africa', 'Ghana', Decimal('227533.00')),
#  ('Western Africa', 'Guinea', Decimal('245720.00')),
#  ('Western Africa', 'Guinea-Bissau', Decimal('28120.00')),
#  ('Western Africa', 'Liberia', Decimal('96320.00')),
#  ('Western Africa', 'Mali', Decimal('1220190.00')),
#  ('Western Africa', 'Mauritania', Decimal('1030700.00')),
#  ('Western Africa', 'Niger', Decimal('1266700.00')),
#  ('Western Africa', 'Nigeria', Decimal('910770.00')),
#  ('Western Africa', 'Senegal', Decimal('192530.00')),
#  ('Western Africa', 'Sierra Leone', Decimal('72180.00')),
#  ('Western Africa', 'Togo', Decimal('54390.00'))]

# %% [markdown]
# ### Task 2: Calculate the land area covered as a percentage of the country's subregion
#
#
# Calculate each land area as a percentage within its sub_region:
# - Divide the `Land_area` by the `SUM()` `BY` the areas `OVER` each `Sub_region`'s `PARTITION`. Name this column `pct_sub_region_land_area`.
# - `Round` the calculation off to `4` decimal places.
#
# Add this line to the query from the first task.

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Land_area,
#     ROUND(Land_area/SUM(Land_area) OVER (PARTITION BY sub_region)*100,4) AS pct_sub_region_land_area
# FROM united_nations.access_to_basic_services
#     WHERE time_period = 2020
#     AND Land_area IS NOT NULL;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 130 rows affected.
# [('Australia and New Zealand', 'Australia', Decimal('7692020.00'), Decimal('96.6901')),
#  ('Australia and New Zealand', 'New Zealand', Decimal('263310.00'), Decimal('3.3099')),
#  ('Caribbean', 'Jamaica', Decimal('10830.00'), Decimal('5.2809')),
#  ('Caribbean', 'Trinidad and Tobago', Decimal('5130.00'), Decimal('2.5015')),
#  ('Caribbean', 'Barbados', Decimal('430.00'), Decimal('0.2097')),
#  ('Caribbean', 'British Virgin Islands', Decimal('150.00'), Decimal('0.0731')),
#  ('Caribbean', 'Cuba', Decimal('103800.00'), Decimal('50.6144')),
#  ('Caribbean', 'Dominican Republic', Decimal('48310.00'), Decimal('23.5567')),
#  ('Caribbean', 'Haiti', Decimal('27560.00'), Decimal('13.4387')),
#  ('Caribbean', 'Puerto Rico', Decimal('8870.00'), Decimal('4.3251')),
#  ('Central America', 'Nicaragua', Decimal('120340.00'), Decimal('4.9076')),
#  ('Central America', 'Mexico', Decimal('1943950.00'), Decimal('79.2766')),
#  ('Central America', 'Honduras', Decimal('111890.00'), Decimal('4.5630')),
#  ('Central America', 'Guatemala', Decimal('107160.00'), Decimal('4.3701')),
#  ('Central America', 'El Salvador', Decimal('20720.00'), Decimal('0.8450')),
#  ('Central America', 'Panama', Decimal('74180.00'), Decimal('3.0251')),
#  ('Central America', 'Costa Rica', Decimal('51060.00'), Decimal('2.0823')),
#  ('Central America', 'Belize', Decimal('22810.00'), Decimal('0.9302')),
#  ('Central Asia', 'Tajikistan', Decimal('138790.00'), Decimal('3.7020')),
#  ('Central Asia', 'Turkmenistan', Decimal('469930.00'), Decimal('12.5346')),
#  ('Central Asia', 'Uzbekistan', Decimal('440650.00'), Decimal('11.7536')),
#  ('Central Asia', 'Kazakhstan', Decimal('2699700.00'), Decimal('72.0099')),
#  ('Eastern Africa', 'Mauritius', Decimal('2030.00'), Decimal('0.0348')),
#  ('Eastern Africa', 'Malawi', Decimal('94280.00'), Decimal('1.6183')),
#  ('Eastern Africa', 'Madagascar', Decimal('581800.00'), Decimal('9.9867')),
#  ('Eastern Africa', 'Kenya', Decimal('569140.00'), Decimal('9.7694')),
#  ('Eastern Africa', 'Djibouti', Decimal('23180.00'), Decimal('0.3979')),
#  ('Eastern Africa', 'Burundi', Decimal('25680.00'), Decimal('0.4408')),
#  ('Eastern Africa', 'Uganda', Decimal('200520.00'), Decimal('3.4420')),
#  ('Eastern Africa', 'Mozambique', Decimal('786380.00'), Decimal('13.4983')),
#  ('Eastern Africa', 'Ethiopia', Decimal('1128571.26'), Decimal('19.3721')),
#  ('Eastern Africa', 'South Sudan', Decimal('631930.00'), Decimal('10.8472')),
#  ('Eastern Africa', 'Somalia', Decimal('627340.00'), Decimal('10.7684')),
#  ('Eastern Africa', 'Rwanda', Decimal('24670.00'), Decimal('0.4235')),
#  ('Eastern Africa', 'Zimbabwe', Decimal('386850.00'), Decimal('6.6403')),
#  ('Eastern Africa', 'Zambia', Decimal('743390.00'), Decimal('12.7604')),
#  ('Eastern Asia', 'China', Decimal('9424702.90'), Decimal('83.0611')),
#  ('Eastern Asia', 'Japan', Decimal('364500.00'), Decimal('3.2124')),
#  ('Eastern Asia', 'Mongolia', Decimal('1557506.80'), Decimal('13.7265')),
#  ('Melanesia', 'Vanuatu', Decimal('12190.00'), Decimal('2.3018')),
#  ('Melanesia', 'Fiji', Decimal('18270.00'), Decimal('3.4498')),
#  ('Melanesia', 'Solomon Islands', Decimal('27990.00'), Decimal('5.2852')),
#  ('Melanesia', 'Papua New Guinea', Decimal('452860.00'), Decimal('85.5114')),
#  ('Melanesia', 'New Caledonia', Decimal('18280.00'), Decimal('3.4517')),
#  ('Micronesia', 'Guam', Decimal('540.00'), Decimal('21.8623')),
#  ('Micronesia', 'Kiribati', Decimal('810.00'), Decimal('32.7935')),
#  ('Micronesia', 'Northern Mariana Islands', Decimal('460.00'), Decimal('18.6235')),
#  ('Micronesia', 'Palau', Decimal('460.00'), Decimal('18.6235')),
#  ('Micronesia', 'Nauru', Decimal('20.00'), Decimal('0.8097')),
#  ('Micronesia', 'Marshall Islands', Decimal('180.00'), Decimal('7.2874')),
#  ('Middle Africa', 'Angola', Decimal('1246700.00'), Decimal('32.2961')),
#  ('Middle Africa', 'Cameroon', Decimal('472710.00'), Decimal('12.2457')),
#  ('Middle Africa', 'Central African Republic', Decimal('622980.00'), Decimal('16.1385')),
#  ('Middle Africa', 'Chad', Decimal('1259200.00'), Decimal('32.6199')),
#  ('Middle Africa', 'Gabon', Decimal('257670.00'), Decimal('6.6750')),
#  ('Middle Africa', 'Sao Tome and Principe', Decimal('960.00'), Decimal('0.0249')),
#  ('Northern Africa', 'Algeria', Decimal('2381741.00'), Decimal('36.0273')),
#  ('Northern Africa', 'Libya', Decimal('1759540.00'), Decimal('26.6156')),
#  ('Northern Africa', 'Morocco', Decimal('446300.00'), Decimal('6.7509')),
#  ('Northern Africa', 'Tunisia', Decimal('155360.00'), Decimal('2.3500')),
#  ('Northern Africa', 'Sudan', Decimal('1868000.00'), Decimal('28.2562')),
#  ('Northern America', 'Canada', Decimal('8965590.00'), Decimal('95.6218')),
#  ('Northern America', 'Greenland', Decimal('410450.00'), Decimal('4.3776')),
#  ('Northern America', 'Bermuda', Decimal('54.00'), Decimal('0.0006')),
#  ('Polynesia', 'Tuvalu', Decimal('30.00'), Decimal('0.4166')),
#  ('Polynesia', 'Tonga', Decimal('720.00'), Decimal('9.9986')),
#  ('Polynesia', 'Samoa', Decimal('2780.00'), Decimal('38.6057')),
#  ('Polynesia', 'American Samoa', Decimal('200.00'), Decimal('2.7774')),
#  ('Polynesia', 'French Polynesia', Decimal('3471.00'), Decimal('48.2016')),
#  ('South America', 'Colombia', Decimal('1109500.00'), Decimal('7.2039')),
#  ('South America', 'Ecuador', Decimal('248360.00'), Decimal('1.6126')),
#  ('South America', 'Guyana', Decimal('196850.00'), Decimal('1.2781')),
#  ('South America', 'Peru', Decimal('1280000.00'), Decimal('8.3109')),
#  ('South America', 'Suriname', Decimal('156000.00'), Decimal('1.0129')),
#  ('South America', 'Uruguay', Decimal('175020.00'), Decimal('1.1364')),
#  ('South America', 'Paraguay', Decimal('397300.00'), Decimal('2.5796')),
#  ('South America', 'Argentina', Decimal('2736690.00'), Decimal('17.7691')),
#  ('South America', 'Brazil', Decimal('8358140.00'), Decimal('54.2687')),
#  ('South America', 'Chile', Decimal('743532.00'), Decimal('4.8277')),
#  ('South-Eastern Asia', 'Philippines', Decimal('298170.00'), Decimal('7.7143')),
#  ('South-Eastern Asia', 'Cambodia', Decimal('176520.00'), Decimal('4.5669')),
#  ('South-Eastern Asia', 'Timor-Leste', Decimal('14870.00'), Decimal('0.3847')),
#  ('South-Eastern Asia', 'Thailand', Decimal('510890.00'), Decimal('13.2178')),
#  ('South-Eastern Asia', 'Singapore', Decimal('718.00'), Decimal('0.0186')),
#  ('South-Eastern Asia', 'Myanmar', Decimal('652670.00'), Decimal('16.8859')),
#  ('South-Eastern Asia', 'Malaysia', Decimal('328550.00'), Decimal('8.5003')),
#  ('South-Eastern Asia', 'Indonesia', Decimal('1877519.00'), Decimal('48.5752')),
#  ('South-Eastern Asia', 'Brunei Darussalam', Decimal('5270.00'), Decimal('0.1363')),
#  ('Southern Africa', 'Lesotho', Decimal('30360.00'), Decimal('1.1454')),
#  ('Southern Africa', 'Eswatini', Decimal('17200.00'), Decimal('0.6489')),
#  ('Southern Africa', 'Botswana', Decimal('566730.00'), Decimal('21.3806')),
#  ('Southern Africa', 'South Africa', Decimal('1213090.00'), Decimal('45.7654')),
#  ('Southern Africa', 'Namibia', Decimal('823290.00'), Decimal('31.0597')),
#  ('Southern Asia', 'Pakistan', Decimal('770880.00'), Decimal('16.1606')),
#  ('Southern Asia', 'Sri Lanka', Decimal('61860.00'), Decimal('1.2968')),
#  ('Southern Asia', 'Nepal', Decimal('143350.00'), Decimal('3.0052')),
#  ('Southern Asia', 'Maldives', Decimal('300.00'), Decimal('0.0063')),
#  ('Southern Asia', 'India', Decimal('2973190.00'), Decimal('62.3295')),
#  ('Southern Asia', 'Bhutan', Decimal('38140.00'), Decimal('0.7996')),
#  ('Southern Asia', 'Bangladesh', Decimal('130170.00'), Decimal('2.7289')),
#  ('Southern Asia', 'Afghanistan', Decimal('652230.00'), Decimal('13.6732')),
#  ('Western Africa', 'Senegal', Decimal('192530.00'), Decimal('3.3568')),
#  ('Western Africa', 'Sierra Leone', Decimal('72180.00'), Decimal('1.2585')),
#  ('Western Africa', 'Togo', Decimal('54390.00'), Decimal('0.9483')),
#  ('Western Africa', 'Mali', Decimal('1220190.00'), Decimal('21.2742')),
#  ('Western Africa', 'Benin', Decimal('112760.00'), Decimal('1.9660')),
#  ('Western Africa', 'Burkina Faso', Decimal('273600.00'), Decimal('4.7703')),
#  ('Western Africa', 'Cabo Verde', Decimal('4030.00'), Decimal('0.0703')),
#  ('Western Africa', 'Ghana', Decimal('227533.00'), Decimal('3.9671')),
#  ('Western Africa', 'Guinea', Decimal('245720.00'), Decimal('4.2842')),
#  ('Western Africa', 'Guinea-Bissau', Decimal('28120.00'), Decimal('0.4903')),
#  ('Western Africa', 'Liberia', Decimal('96320.00'), Decimal('1.6794')),
#  ('Western Africa', 'Mauritania', Decimal('1030700.00'), Decimal('17.9704')),
#  ('Western Africa', 'Niger', Decimal('1266700.00'), Decimal('22.0851')),
#  ('Western Africa', 'Nigeria', Decimal('910770.00'), Decimal('15.8794')),
#  ('Western Asia', 'Jordan', Decimal('88794.00'), Decimal('2.5453')),
#  ('Western Asia', 'Armenia', Decimal('28470.00'), Decimal('0.8161')),
#  ('Western Asia', 'Kuwait', Decimal('17820.00'), Decimal('0.5108')),
#  ('Western Asia', 'Georgia', Decimal('69490.00'), Decimal('1.9919')),
#  ('Western Asia', 'Cyprus', Decimal('9240.00'), Decimal('0.2649')),
#  ('Western Asia', 'Bahrain', Decimal('785.00'), Decimal('0.0225')),
#  ('Western Asia', 'Azerbaijan', Decimal('82646.00'), Decimal('2.3690')),
#  ('Western Asia', 'Syrian Arab Republic', Decimal('183630.00'), Decimal('5.2638')),
#  ('Western Asia', 'United Arab Emirates', Decimal('71020.00'), Decimal('2.0358')),
#  ('Western Asia', 'Saudi Arabia', Decimal('2149690.00'), Decimal('61.6209')),
#  ('Western Asia', 'Qatar', Decimal('11490.00'), Decimal('0.3294')),
#  ('Western Asia', 'Oman', Decimal('309500.00'), Decimal('8.8718')),
#  ('Western Asia', 'Lebanon', Decimal('10230.00'), Decimal('0.2932')),
#  ('Western Asia', 'Israel', Decimal('21640.00'), Decimal('0.6203')),
#  ('Western Asia', 'Iraq', Decimal('434128.00'), Decimal('12.4443'))]

# %% [markdown]
# ### Task 3: Calculate The running population average for each country's subregion
#
# Start by selecting the columns needed for this analysis:
# - `Sub_region`
# - `Country_name`
# - `Time_period`
# - `Pct_managed_drinking_water_services`
# - `Pct_managed_sanitation_services`
# - `Est_gdp_in_billions`
# - `Est_population_in_millions`
#
# Calculate the running average:
# - Calculate the `AVG()` of the `Est_population_in_millions`.
# - `PARTITION` the calculation `OVER` each country's `Sub_region`, and name this column `Running_average_population`.
# - `ROUND` the calculation off to `4` decimal places.
# - Filter the results `WHERE` there are values of `Est_gdp_in_billions` that are `NOT NULL`.

# %%
# %%sql
# -- Add your code here

# %% [markdown]
# ## Solutions
#
# ### Task 1: Select the data required for the analysis

# %%
# %%sql
# SELECT
# 	Sub_region,
#     Country_name,
#     Land_area
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020
# AND Land_area IS NOT NULL;

# %% [markdown]
# ### Task 2: Calculate the land area covered as a percentage of the country's subregion

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Land_area,
#     ROUND(Land_area/SUM(Land_area) OVER (PARTITION BY sub_region)*100,4) AS pct_sub_region_land_area
# FROM united_nations.access_to_basic_services
#     WHERE time_period = 2020
#     AND Land_area IS NOT NULL;

# %% [markdown]
# ### Task 3: Calculate The running population average for each country's subregion

# %%
# %%sql
# SELECT
#     Sub_region,
#     Country_name,
#     Time_period,
#     Pct_managed_drinking_water_services,
#     Pct_managed_sanitation_services,
#     Est_gdp_in_billions,
#     Est_population_in_millions,
#     ROUND(AVG(Est_population_in_millions) OVER (PARTITION BY Sub_region ORDER BY Time_period),4) AS Running_average_population
# FROM united_nations.access_to_basic_services
#     WHERE Est_gdp_in_billions IS NOT NULL;

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
